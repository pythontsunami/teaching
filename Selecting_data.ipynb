# %% [markdown]
# # Selecting data

# %%
import numpy as np

# %% [markdown]
# ## Booleans

# %%
 3 > 4
# Out:
# False

# %%
3 < 4
# Out:
# True

# %%
3 < 4 and 4 < 10
# Out:
# True

# %%
(3 < 4) and (4 < 10)
# Out:
# True

# %%
(3 < 4) or (4 < 10)
# Out:
# True

# %%
(3 > 4) or (4 < 10)
# Out:
# True

# %%
not (3 < 4) or (4 < 10)
# Out:
# True

# %%
not (3 < 4) and (4 < 10)
# Out:
# False

# %%
not (3 > 4) and (4 < 10)
# Out:
# True

# %% [markdown]
# ### Boolean operators
#
# `and`, `a and b`
#
# `or`, `a or b`
#
# `not`, `not a`

# %% [markdown]
# ### Comparison operators
#
# `==`, equal to, `a == b`
#
# `>`, greater than, `a > b`
#
# `>=`, greater than or equal to, `a >= b`
#
# `<`, less than, `a < b`
#
# `<=`, less than or equal to, `a <= b`

# %% [markdown]
# ## Selecting data in a numpy array

# %%
x = np.array([4,5,6,24,63,1])
x
# Out:
# array([ 4,  5,  6, 24, 63,  1])

# %%
x > 10
# Out:
# array([False, False, False,  True,  True, False])

# %%
(x > 10) & (x < 50)
# Out:
# array([False, False, False,  True, False, False])

# %%
x == 24
# Out:
# array([False, False, False,  True, False, False])

# %%
x != 24
# Out:
# array([ True,  True,  True, False,  True,  True])

# %%
x >= 24
# Out:
# array([False, False, False,  True,  True, False])

# %%
x <= 24
# Out:
# array([ True,  True,  True,  True, False,  True])

# %%
np.all(x > 5)
# Out:
# False

# %%
np.all(x < 100)
# Out:
# True

# %%
np.any(x > 5)
# Out:
# True

# %%
np.any(x < 100)
# Out:
# True

# %% [markdown]
# Getting the entries that satisfy the above conditions

# %%
x
# Out:
# array([ 4,  5,  6, 24, 63,  1])

# %%
x > 10
# Out:
# array([False, False, False,  True,  True, False])

# %%
x[x > 10]
# Out:
# array([24, 63])

# %%
x[(x > 10) & (x < 50)]
# Out:
# array([24])

# %%
x[x > 10 & x < 50]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e596cae7e984> in <module>
# ----> 1 x[x > 10 & x < 50]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
x[(x > 10) and (x < 50)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-0add49ee7a3e> in <module>
# ----> 1 x[(x > 10) and (x < 50)]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
x[x > 10 and x < 50]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-94944093d785> in <module>
# ----> 1 x[x > 10 and x < 50]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
x = np.array([[4,5,6,24,63,1], [45,134,6,2,1,7]])
x
# Out:
# array([[  4,   5,   6,  24,  63,   1],
#        [ 45, 134,   6,   2,   1,   7]])

# %%
x[x > 10]
# Out:
# array([ 24,  63,  45, 134])

# %%
x[x % 2 == 0]
# Out:
# array([  4,   6,  24, 134,   6,   2])

# %% [markdown]
# ## Exercises

# %% [markdown]
# #### 1. Sum all numbers greater than 50

# %% [markdown]
# #### 2. Count the number of elements greater than 50
#
# Hint: np.count_nonzero()

# %% [markdown]
# #### 3. Find  the odd and even numbers in the array above

# %% [markdown]
# Hint: x % 2 gives you the remainder of the division of x by 2
