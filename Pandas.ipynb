# %% [markdown]
# # Pandas

# %% [markdown]
# Kind of excel for python :)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Import data from csv file

# %%
df = pd.read_csv('data/per-capita-electricity-consumption.csv', sep=',')
df
# Out:
#         Entity Code  Year  \
# 0      Albania  ALB  1971
# 1      Albania  ALB  1972
# 2      Albania  ALB  1973
# 3      Albania  ALB  1974
# 4      Albania  ALB  1975
# 5      Albania  ALB  1976
# 6      Albania  ALB  1977
# 7      Albania  ALB  1978
# 8      Albania  ALB  1979
# 9      Albania  ALB  1980
# 10     Albania  ALB  1981
# 11     Albania  ALB  1982
# 12     Albania  ALB  1983
# 13     Albania  ALB  1984
# 14     Albania  ALB  1985
# 15     Albania  ALB  1986
# 16     Albania  ALB  1987
# 17     Albania  ALB  1988
# 18     Albania  ALB  1989
# 19     Albania  ALB  1990
# 20     Albania  ALB  1991
# 21     Albania  ALB  1992
# 22     Albania  ALB  1993
# 23     Albania  ALB  1994
# 24     Albania  ALB  1995
# 25     Albania  ALB  1996
# 26     Albania  ALB  1997
# 27     Albania  ALB  1998
# 28     Albania  ALB  1999
# 29     Albania  ALB  2000
# ...        ...  ...   ...
# 7659  Zimbabwe  ZWE  1985
# 7660  Zimbabwe  ZWE  1986
# 7661  Zimbabwe  ZWE  1987
# ...

# %% [markdown]
# Import data from excel file

# %%
df = pd.read_excel('data/per-capita-electricity-consumption.xlsx', sheet_name='per-capita-electricity-consumption')
df
# Out:
#         Entity Code  Year  \
# 0      Albania  ALB  1971
# 1      Albania  ALB  1972
# 2      Albania  ALB  1973
# 3      Albania  ALB  1974
# 4      Albania  ALB  1975
# 5      Albania  ALB  1976
# 6      Albania  ALB  1977
# 7      Albania  ALB  1978
# 8      Albania  ALB  1979
# 9      Albania  ALB  1980
# 10     Albania  ALB  1981
# 11     Albania  ALB  1982
# 12     Albania  ALB  1983
# 13     Albania  ALB  1984
# 14     Albania  ALB  1985
# 15     Albania  ALB  1986
# 16     Albania  ALB  1987
# 17     Albania  ALB  1988
# 18     Albania  ALB  1989
# 19     Albania  ALB  1990
# 20     Albania  ALB  1991
# 21     Albania  ALB  1992
# 22     Albania  ALB  1993
# 23     Albania  ALB  1994
# 24     Albania  ALB  1995
# 25     Albania  ALB  1996
# 26     Albania  ALB  1997
# 27     Albania  ALB  1998
# 28     Albania  ALB  1999
# 29     Albania  ALB  2000
# ...        ...  ...   ...
# 7659  Zimbabwe  ZWE  1985
# 7660  Zimbabwe  ZWE  1986
# 7661  Zimbabwe  ZWE  1987
# ...

# %%
df.head(10)
# Out:
#     Entity Code  Year  \
# 0  Albania  ALB  1971
# 1  Albania  ALB  1972
# 2  Albania  ALB  1973
# 3  Albania  ALB  1974
# 4  Albania  ALB  1975
# 5  Albania  ALB  1976
# 6  Albania  ALB  1977
# 7  Albania  ALB  1978
# 8  Albania  ALB  1979
# 9  Albania  ALB  1980
#
#    Electric power consumption (kWh per capita) (kWh per capita)
# 0                                         532.028432
# 1                                         568.403202
# 2                                         593.446746
# 3                                         591.032643
# 4                                         739.345093
# 5                                         908.674547
# 6                                        1067.814156
# 7                                        1098.483166
# 8                                        1065.767398
# 9                                        1142.965355

# %%
df.tail(10)
# Out:
#         Entity Code  Year  \
# 7679  Zimbabwe  ZWE  2005
# 7680  Zimbabwe  ZWE  2006
# 7681  Zimbabwe  ZWE  2007
# 7682  Zimbabwe  ZWE  2008
# 7683  Zimbabwe  ZWE  2009
# 7684  Zimbabwe  ZWE  2010
# 7685  Zimbabwe  ZWE  2011
# 7686  Zimbabwe  ZWE  2012
# 7687  Zimbabwe  ZWE  2013
# 7688  Zimbabwe  ZWE  2014
#
#       Electric power consumption (kWh per capita) (kWh per capita)
# 7679                                         832.378158
# 7680                                         807.587959
# 7681                                         698.954509
# 7682                                         573.294817
# 7683                                         531.041412
# 7684                                         546.842727
# 7685                                         570.250932
# 7686                                         542.729552
# 7687                                         557.573925
# 7688                                         536.995492

# %%
df.sample(5)
# Out:
#            Entity Code  Year  \
# 3988       Latvia  LVA  1994
# 571         Benin  BEN  1994
# 860      Cameroon  CMR  1984
# 4971  Netherlands  NLD  1980
# 4472       Mexico  MEX  1977
#
#       Electric power consumption (kWh per capita) (kWh per capita)
# 3988                                        1973.228518
# 571                                           39.375453
# 860                                          204.983175
# 4971                                        4364.160624
# 4472                                         720.512286

# %% [markdown]
# Check dataframe shape

# %%
df.shape
# Out:
# (7689, 4)

# %% [markdown]
# Get the data from a given column, by name

# %%
df['Entity']
# Out:
# 0        Albania
# 1        Albania
# 2        Albania
# 3        Albania
# 4        Albania
# 5        Albania
# 6        Albania
# 7        Albania
# 8        Albania
# 9        Albania
# 10       Albania
# 11       Albania
# 12       Albania
# 13       Albania
# 14       Albania
# 15       Albania
# 16       Albania
# 17       Albania
# 18       Albania
# 19       Albania
# 20       Albania
# 21       Albania
# 22       Albania
# 23       Albania
# 24       Albania
# 25       Albania
# 26       Albania
# 27       Albania
# 28       Albania
# 29       Albania
#           ...
# 7659    Zimbabwe
# 7660    Zimbabwe
# 7661    Zimbabwe
# 7662    Zimbabwe
# 7663    Zimbabwe
# 7664    Zimbabwe
# 7665    Zimbabwe
# 7666    Zimbabwe
# 7667    Zimbabwe
# 7668    Zimbabwe
# 7669    Zimbabwe
# 7670    Zimbabwe
# 7671    Zimbabwe
# 7672    Zimbabwe
# 7673    Zimbabwe
# 7674    Zimbabwe
# 7675    Zimbabwe
# 7676    Zimbabwe
# 7677    Zimbabwe
# 7678    Zimbabwe
# 7679    Zimbabwe
# ...

# %%
df['Entity'].unique()
# Out:
# array(['Albania', 'Algeria', 'Angola', 'Arab World', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Benin', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei',
#        'Bulgaria', 'Cambodia', 'Cameroon', 'Canada',
#        'Caribbean small states', 'Central Europe and the Baltics',
#        'Chile', 'China', 'Colombia', 'Congo', 'Costa Rica',
#        "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus',
#        'Czech Republic', 'Democratic Republic of Congo', 'Denmark',
#        'Dominican Republic', 'Early-demographic dividend',
#        'East Asia & Pacific', 'East Asia & Pacific (IDA & IBRD)',
#        'East Asia & Pacific (excluding high income)', 'Ecuador', 'Egypt',
#        'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Euro area',
#        'Europe & Central Asia', 'Europe & Central Asia (IDA & IBRD)',
# ...

# %%
df['Entity'].values
# Out:
# array(['Albania', 'Albania', 'Albania', ..., 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe'], dtype=object)

# %% [markdown]
# Get the data from a given column, by position

# %%
df.iloc[:, 2]
# Out:
# 0       1971
# 1       1972
# 2       1973
# 3       1974
# 4       1975
# 5       1976
# 6       1977
# 7       1978
# 8       1979
# 9       1980
# 10      1981
# 11      1982
# 12      1983
# 13      1984
# 14      1985
# 15      1986
# 16      1987
# 17      1988
# 18      1989
# 19      1990
# 20      1991
# 21      1992
# 22      1993
# 23      1994
# 24      1995
# 25      1996
# 26      1997
# 27      1998
# 28      1999
# 29      2000
#         ...
# 7659    1985
# 7660    1986
# 7661    1987
# 7662    1988
# 7663    1989
# 7664    1990
# 7665    1991
# 7666    1992
# 7667    1993
# 7668    1994
# 7669    1995
# 7670    1996
# 7671    1997
# 7672    1998
# 7673    1999
# 7674    2000
# 7675    2001
# 7676    2002
# 7677    2003
# 7678    2004
# 7679    2005
# 7680    2006
# 7681    2007
# 7682    2008
# 7683    2009
# 7684    2010
# 7685    2011
# 7686    2012
# 7687    2013
# 7688    2014
# Name: Year, Length: 7689, dtype: int64

# %% [markdown]
# Get the data for a given row, by name

# %%
df.loc[7680]
# Out:
# Entity                                                          Zimbabwe
# Code                                                                 ZWE
# Year                                                                2006
# Electric power consumption (kWh per capita) (kWh per capita)     807.588
# Name: 7680, dtype: object

# %% [markdown]
# Get the data for a given row, by position

# %%
df.iloc[7680]
# Out:
# Entity                                                          Zimbabwe
# Code                                                                 ZWE
# Year                                                                2006
# Electric power consumption (kWh per capita) (kWh per capita)     807.588
# Name: 7680, dtype: object

# %% [markdown]
# Access a certain cell by col and row name

# %%
df.loc[7680, 'Entity']
# Out:
# 'Zimbabwe'

# %% [markdown]
# Access a certain cell by col and row index

# %%
df.iloc[7680, 1]
# Out:
# 'ZWE'

# %% [markdown]
# Select data for a given country

# %%
df_germany = df[df['Entity'] == 'Germany']
df_germany
# Out:
#        Entity Code  Year  \
# 2416  Germany  DEU  1960
# 2417  Germany  DEU  1961
# 2418  Germany  DEU  1962
# 2419  Germany  DEU  1963
# 2420  Germany  DEU  1964
# 2421  Germany  DEU  1965
# 2422  Germany  DEU  1966
# 2423  Germany  DEU  1967
# 2424  Germany  DEU  1968
# 2425  Germany  DEU  1969
# 2426  Germany  DEU  1970
# 2427  Germany  DEU  1971
# 2428  Germany  DEU  1972
# 2429  Germany  DEU  1973
# 2430  Germany  DEU  1974
# 2431  Germany  DEU  1975
# 2432  Germany  DEU  1976
# 2433  Germany  DEU  1977
# 2434  Germany  DEU  1978
# 2435  Germany  DEU  1979
# 2436  Germany  DEU  1980
# 2437  Germany  DEU  1981
# 2438  Germany  DEU  1982
# 2439  Germany  DEU  1983
# 2440  Germany  DEU  1984
# 2441  Germany  DEU  1985
# 2442  Germany  DEU  1986
# 2443  Germany  DEU  1987
# 2444  Germany  DEU  1988
# 2445  Germany  DEU  1989
# 2446  Germany  DEU  1990
# 2447  Germany  DEU  1991
# 2448  Germany  DEU  1992
# 2449  Germany  DEU  1993
# 2450  Germany  DEU  1994
# ...

# %%
df_germany.plot(x='Year', y = 'Electric power consumption (kWh per capita) (kWh per capita)')

# %%
col_names = df.columns.values
col_names[-1] = 'Electricity consumption'
df.columns = col_names
df.head()
# Out:
#     Entity Code  Year  Electricity consumption
# 0  Albania  ALB  1971               532.028432
# 1  Albania  ALB  1972               568.403202
# 2  Albania  ALB  1973               593.446746
# 3  Albania  ALB  1974               591.032643
# 4  Albania  ALB  1975               739.345093

# %% [markdown]
# ### Group data and summarize it

# %% [markdown]
# Get mean electricity consumption over time per country

# %%
df.groupby('Entity').mean()
# Out:
#                                               Year  \
# Entity
# Albania                                     1992.5
# Algeria                                     1992.5
# Angola                                      1992.5
# Arab World                                  1992.5
# Argentina                                   1992.5
# Armenia                                     2002.0
# Australia                                   1987.0
# Austria                                     1987.0
# Azerbaijan                                  2002.0
# Bahrain                                     1992.5
# Bangladesh                                  1992.5
# Belarus                                     2002.0
# Belgium                                     1987.0
# Benin                                       1992.5
# Bolivia                                     1992.5
# Bosnia and Herzegovina                      2002.0
# Botswana                                    1997.5
# ...

# %%
df.groupby('Entity').min() # max
# Out:
#                                                 Code  Year  \
# Entity
# Albania                                          ALB  1971
# Algeria                                          DZA  1971
# Angola                                           AGO  1971
# Arab World                                       NaN  1971
# Argentina                                        ARG  1971
# Armenia                                          ARM  1990
# Australia                                        AUS  1960
# Austria                                          AUT  1960
# Azerbaijan                                       AZE  1990
# Bahrain                                          BHR  1971
# Bangladesh                                       BGD  1971
# Belarus                                          BLR  1990
# Belgium                                          BEL  1960
# Benin                                            BEN  1971
# Bolivia                                          BOL  1971
# ...

# %%
df[df['Entity'] == 'Albania']['Electricity consumption'].min()
# Out:
# 418.45358899714995

# %%
df[df['Entity'] == 'Albania']['Year'].min()
# Out:
# 1971

# %%
df.groupby('Entity').median()
# Out:
#                                               Year  Electricity consumption
# Entity
# Albania                                     1992.5              1083.781697
# Algeria                                     1992.5               546.552611
# Angola                                      1992.5                69.932553
# Arab World                                  1992.5              1089.489714
# Argentina                                   1992.5              1468.624887
# Armenia                                     2002.0              1521.504841
# Australia                                   1987.0              7525.685721
# Austria                                     1987.0              5536.144154
# Azerbaijan                                  2002.0              2052.650965
# Bahrain                                     1992.5             17652.907455
# Bangladesh                                  1992.5                61.928987
# ...

# %%
df.groupby('Entity').median().apply(np.sqrt)
# Out:
#                                                  Year  Electricity consumption
# Entity
# Albania                                     44.637428                32.920840
# Algeria                                     44.637428                23.378465
# Angola                                      44.637428                 8.362569
# Arab World                                  44.637428                33.007419
# Argentina                                   44.637428                38.322642
# Armenia                                     44.743715                39.006472
# Australia                                   44.575778                86.750710
# Austria                                     44.575778                74.405270
# Azerbaijan                                  44.743715                45.306191
# Bahrain                                     44.637428               132.864244
# Bangladesh                                  44.637428                 7.869497
# ...

# %% [markdown]
# ### Manipulate data frame

# %% [markdown]
# Remove a column

# %%
df = df.drop('Code', axis=1)
df
# Out:
#         Entity  Year  Electricity consumption
# 0      Albania  1971               532.028432
# 1      Albania  1972               568.403202
# 2      Albania  1973               593.446746
# 3      Albania  1974               591.032643
# 4      Albania  1975               739.345093
# 5      Albania  1976               908.674547
# 6      Albania  1977              1067.814156
# 7      Albania  1978              1098.483166
# 8      Albania  1979              1065.767398
# 9      Albania  1980              1142.965355
# 10     Albania  1981              1123.968106
# 11     Albania  1982              1096.873229
# 12     Albania  1983              1070.690164
# 13     Albania  1984              1018.100288
# 14     Albania  1985               796.353974
# 15     Albania  1986              1420.614795
# 16     Albania  1987              1161.951677
# 17     Albania  1988              1005.939530
# 18     Albania  1989              1021.393500
# ...

# %% [markdown]
# Define the index (i.e. row label) to be the year

# %%
df.index = df['Year']
df
# Out:
#         Entity  Year  Electricity consumption
# Year
# 1971   Albania  1971               532.028432
# 1972   Albania  1972               568.403202
# 1973   Albania  1973               593.446746
# 1974   Albania  1974               591.032643
# 1975   Albania  1975               739.345093
# 1976   Albania  1976               908.674547
# 1977   Albania  1977              1067.814156
# 1978   Albania  1978              1098.483166
# 1979   Albania  1979              1065.767398
# 1980   Albania  1980              1142.965355
# 1981   Albania  1981              1123.968106
# 1982   Albania  1982              1096.873229
# 1983   Albania  1983              1070.690164
# 1984   Albania  1984              1018.100288
# 1985   Albania  1985               796.353974
# 1986   Albania  1986              1420.614795
# 1987   Albania  1987              1161.951677
# 1988   Albania  1988              1005.939530
# 1989   Albania  1989              1021.393500
# ...

# %% [markdown]
# Remove a column

# %%
df = df.drop('Year', axis=1)
df
# Out:
#         Entity  Electricity consumption
# Year
# 1971   Albania               532.028432
# 1972   Albania               568.403202
# 1973   Albania               593.446746
# 1974   Albania               591.032643
# 1975   Albania               739.345093
# 1976   Albania               908.674547
# 1977   Albania              1067.814156
# 1978   Albania              1098.483166
# 1979   Albania              1065.767398
# 1980   Albania              1142.965355
# 1981   Albania              1123.968106
# 1982   Albania              1096.873229
# 1983   Albania              1070.690164
# 1984   Albania              1018.100288
# 1985   Albania               796.353974
# 1986   Albania              1420.614795
# 1987   Albania              1161.951677
# 1988   Albania              1005.939530
# 1989   Albania              1021.393500
# 1990   Albania               552.252185
# 1991   Albania               418.453589
# 1992   Albania               453.644074
# ...

# %%
df = df.pivot(columns='Entity', values='Electricity consumption')
df
# Out:
# Entity      Albania      Algeria      Angola   Arab World    Argentina  \
# Year
# 1960            NaN          NaN         NaN          NaN          NaN
# 1961            NaN          NaN         NaN          NaN          NaN
# 1962            NaN          NaN         NaN          NaN          NaN
# 1963            NaN          NaN         NaN          NaN          NaN
# 1964            NaN          NaN         NaN          NaN          NaN
# 1965            NaN          NaN         NaN          NaN          NaN
# 1966            NaN          NaN         NaN          NaN          NaN
# 1967            NaN          NaN         NaN          NaN          NaN
# 1968            NaN          NaN         NaN          NaN          NaN
# 1969            NaN          NaN         NaN          NaN          NaN
# 1970            NaN          NaN         NaN          NaN          NaN
# 1971     532.028432   133.087266   80.262510   195.163395   870.623730
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
df.fillna(0)
# Out:
# Entity      Albania      Algeria      Angola   Arab World    Argentina  \
# Year
# 1960       0.000000     0.000000    0.000000     0.000000     0.000000
# 1961       0.000000     0.000000    0.000000     0.000000     0.000000
# 1962       0.000000     0.000000    0.000000     0.000000     0.000000
# 1963       0.000000     0.000000    0.000000     0.000000     0.000000
# 1964       0.000000     0.000000    0.000000     0.000000     0.000000
# 1965       0.000000     0.000000    0.000000     0.000000     0.000000
# 1966       0.000000     0.000000    0.000000     0.000000     0.000000
# 1967       0.000000     0.000000    0.000000     0.000000     0.000000
# 1968       0.000000     0.000000    0.000000     0.000000     0.000000
# 1969       0.000000     0.000000    0.000000     0.000000     0.000000
# 1970       0.000000     0.000000    0.000000     0.000000     0.000000
# 1971     532.028432   133.087266   80.262510   195.163395   870.623730
# ...

# %%
df.fillna(method='bfill')
# Out:
# Entity      Albania      Algeria      Angola   Arab World    Argentina  \
# Year
# 1960     532.028432   133.087266   80.262510   195.163395   870.623730
# 1961     532.028432   133.087266   80.262510   195.163395   870.623730
# 1962     532.028432   133.087266   80.262510   195.163395   870.623730
# 1963     532.028432   133.087266   80.262510   195.163395   870.623730
# 1964     532.028432   133.087266   80.262510   195.163395   870.623730
# 1965     532.028432   133.087266   80.262510   195.163395   870.623730
# 1966     532.028432   133.087266   80.262510   195.163395   870.623730
# 1967     532.028432   133.087266   80.262510   195.163395   870.623730
# 1968     532.028432   133.087266   80.262510   195.163395   870.623730
# 1969     532.028432   133.087266   80.262510   195.163395   870.623730
# 1970     532.028432   133.087266   80.262510   195.163395   870.623730
# 1971     532.028432   133.087266   80.262510   195.163395   870.623730
# ...

# %%
df.describe()
# Out:
# Entity      Albania      Algeria      Angola   Arab World    Argentina  \
# count     44.000000    44.000000   44.000000    44.000000    44.000000
# mean    1167.184793   590.556227   96.590290  1213.052610  1735.595646
# std      537.897825   310.932473   65.063112   682.529071   662.916309
# min      418.453589   133.087266   48.146351   195.163395   870.623730
# 25%      724.803636   393.040491   53.776439   686.803703  1227.722333
# 50%     1083.781697   546.552611   69.932553  1089.489714  1468.624887
# 75%     1454.551695   787.450346  112.311634  1723.376823  2195.612817
# max     2533.252829  1356.264554  312.476017  2489.220073  3052.381937
#
# Entity      Armenia     Australia      Austria   Azerbaijan       Bahrain  \
# count     25.000000     55.000000    55.000000    25.000000     44.000000
# mean    1606.647290   7073.184175  5393.980049  2087.194710  14185.729820
# std      435.331061   3051.306130  2136.438092   270.388284   7260.057826
# ...

# %%
df['Germany'].plot()

# %%
df['Germany'].max()
# Out:
# 7281.27217417162

# %%
small_df = df.iloc[:, :20]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,7))
small_df.plot(legend=False, ax=ax)
ax.legend(bbox_to_anchor=(1.1, 0.9))

# %%
df.head()
# Out:
# Entity  Albania  Algeria  Angola  Arab World  Argentina  Armenia    Australia  \
# Year
# 1960        NaN      NaN     NaN         NaN        NaN      NaN  1825.625650
# 1961        NaN      NaN     NaN         NaN        NaN      NaN  1947.152533
# 1962        NaN      NaN     NaN         NaN        NaN      NaN  2012.660585
# 1963        NaN      NaN     NaN         NaN        NaN      NaN  2211.689498
# 1964        NaN      NaN     NaN         NaN        NaN      NaN  2417.211427
#
# Entity      Austria  Azerbaijan  Bahrain  ...  United States  \
# Year                                      ...
# 1960    1814.676017         NaN      NaN  ...    4049.786629
# 1961    1882.223711         NaN      NaN  ...    4182.175501
# 1962    2006.770396         NaN      NaN  ...    4433.606021
# 1963    2124.359184         NaN      NaN  ...    4690.486256
# 1964    2232.896504         NaN      NaN  ...    4970.446456
#
# ...

# %%
df.melt().dropna()
# Out:
#          Entity        value
# 11      Albania   532.028432
# 12      Albania   568.403202
# 13      Albania   593.446746
# 14      Albania   591.032643
# 15      Albania   739.345093
# 16      Albania   908.674547
# 17      Albania  1067.814156
# 18      Albania  1098.483166
# 19      Albania  1065.767398
# 20      Albania  1142.965355
# 21      Albania  1123.968106
# 22      Albania  1096.873229
# 23      Albania  1070.690164
# 24      Albania  1018.100288
# 25      Albania   796.353974
# 26      Albania  1420.614795
# 27      Albania  1161.951677
# 28      Albania  1005.939530
# 29      Albania  1021.393500
# 30      Albania   552.252185
# 31      Albania   418.453589
# 32      Albania   453.644074
# 33      Albania   536.363825
# 34      Albania   596.407959
# 35      Albania   663.783995
# 36      Albania   904.346640
# 37      Albania   694.664803
# 38      Albania   734.849914
# 39      Albania  1414.703784
# 40      Albania  1449.647413
# ...         ...          ...
# ...

# %% [markdown]
# ### Exercise

# %% [markdown]
# #### 1. Plot maximum electricity consumption over the years for the following countries: United States, Spain, Italy, Sweden, Norway, South Africa, China, India.

# %% [markdown]
# Hint: https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
df[['United States', 'Spain', 'Italy', 'Sweden', 'Norway', 'South Africa', 'China', 'India']].max().plot.bar()

# %% [markdown]
# #### 2. Plot the electricity consumption over the years for Norway using matplotlib

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,7))
ax.plot(df.index, df['Germany'])

# %% [markdown]
# ## Plotting with Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data=df)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10))
sns.boxplot(data=small_df, ax=ax)
ax.set_xticklabels(small_df.columns, rotation=90);

# %% [markdown]
# ### Heatmap

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20,10))
sns.heatmap(data=small_df.transpose(), ax=ax, cmap='Blues')
