# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_electricity = pd.read_csv('/home/mrama/Desktop/Notebook exercises/per-capita-electricity-consumption-subset.csv', 
                             sep=',')

# %%
df_electricity.head()
# Out:
#     Entity Code  Year  Electricity consumption
# 0  Albania  ALB  1971               532.028432
# 1  Albania  ALB  1972               568.403202
# 2  Albania  ALB  1973               593.446746
# 3  Albania  ALB  1974               591.032643
# 4  Albania  ALB  1975               739.345093

# %%
df_electricity = pd.read_excel('/home/mrama/Desktop/Notebook exercises/per-capita-electricity-consumption-subset.xlsx',
                              sheet_name='per-capita-electricity-consumption-subset')

# %%
df_electricity.head()
# Out:
#     Entity Code  Year  Electricity consumption
# 0  Albania  ALB  1971               532.028432
# 1  Albania  ALB  1972               568.403202
# 2  Albania  ALB  1973               593.446746
# 3  Albania  ALB  1974               591.032643
# 4  Albania  ALB  1975               739.345093

# %%
df_electricity['Entity'].unique()
# Out:
# array(['Albania', 'Belarus', 'France', 'India', 'Iran', 'Lithuania',
#        'Spain', 'United Kingdom', 'United States', 'Vietnam'],
#       dtype=object)

# %%
df_electricity['Code'].unique()
# Out:
# array(['ALB', 'BLR', 'FRA', 'IND', 'IRN', 'LTU', 'ESP', 'GBR', 'USA',
#        'VNM'], dtype=object)

# %%
del df_electricity['Code']

# %%
df_electricity.head()
# Out:
#     Entity  Year  Electricity consumption
# 0  Albania  1971               532.028432
# 1  Albania  1972               568.403202
# 2  Albania  1973               593.446746
# 3  Albania  1974               591.032643
# 4  Albania  1975               739.345093

# %%
df_electricity = pd.read_excel('/home/mrama/Desktop/Notebook exercises/per-capita-electricity-consumption-subset.xlsx',
                              sheet_name='per-capita-electricity-consumption-subset')

# %%
df_electricity = df_electricity.drop('Code', axis=1)

# %%
df_electricity.head()
# Out:
#     Entity  Year  Electricity consumption
# 0  Albania  1971               532.028432
# 1  Albania  1972               568.403202
# 2  Albania  1973               593.446746
# 3  Albania  1974               591.032643
# 4  Albania  1975               739.345093

# %%
df_electricity.min()
# Out:
# Entity                     Albania
# Year                          1960
# Electricity consumption    33.8846
# dtype: object

# %%
df_electricity.groupby('Entity').median()
# Out:
#                   Year  Electricity consumption
# Entity
# Albania         1992.5              1083.781697
# Belarus         2002.0              3298.703607
# France          1987.0              5634.210191
# India           1992.5               313.623700
# Iran            1992.5              1100.986117
# Lithuania       2002.0              3187.031080
# Spain           1987.0              3094.082265
# United Kingdom  1987.0              5082.439806
# United States   1987.0             10886.858256
# Vietnam         1992.5               106.574125

# %%
df_electricity.groupby('Entity').plot(x='Year', y='Electricity consumption');

# %%
figure, axes = plt.subplots(nrows=1, ncols=1)

df_electricity.groupby('Entity').plot(x='Year', y='Electricity consumption', ax=axes);

# %%
df_electricity.groupby('Entity')['Electricity consumption'].min().plot.bar()

# %%
df_electricity.groupby('Entity').min().plot.bar();

# %%
electricity_belarus = df_electricity[df_electricity['Entity'] == 'Belarus']

# %%
electricity_belarus['Year'].values
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014])

# %%
figure, axes = plt.subplots()
axes.scatter(x=electricity_belarus['Year'].values,
             y=electricity_belarus['Electricity consumption'].values)
axes.set_ylim(0, 4500)
axes.set_xlim(1950, 2020)
# Out:
# (1950, 2020)

# %%
df_electricity['Entity'] == 'Albania'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 416    False
# 417    False
# 418    False
# 419    False
# 420    False
# 421    False
# 422    False
# 423    False
# 424    False
# 425    False
# 426    False
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# 433    False
# 434    False
# 435    False
# 436    False
# 437    False
# 438    False
# 439    False
# 440    False
# 441    False
# 442    False
# 443    False
# 444    False
# 445    False
# Name: Entity, Length: 446, dtype: bool

# %%
electricity_belarus = df_electricity[df_electricity['Entity'] == 'Belarus']

# %%
electricity_belarus
# Out:
#      Entity  Year  Electricity consumption
# 44  Belarus  1990              4380.900972
# 45  Belarus  1991              4426.034923
# 46  Belarus  1992              3912.881754
# 47  Belarus  1993              3450.239281
# 48  Belarus  1994              3068.348489
# 49  Belarus  1995              2789.974495
# 50  Belarus  1996              2806.496063
# 51  Belarus  1997              2953.049323
# 52  Belarus  1998              3016.287615
# 53  Belarus  1999              3005.364257
# 54  Belarus  2000              2996.309475
# 55  Belarus  2001              3009.402482
# 56  Belarus  2002              3000.745625
# 57  Belarus  2003              3063.056939
# 58  Belarus  2004              3174.053092
# 59  Belarus  2005              3245.372088
# 60  Belarus  2006              3365.981865
# 61  Belarus  2007              3393.908536
# 62  Belarus  2008              3481.743517
# 63  Belarus  2009              3298.703607
# 64  Belarus  2010              3563.637766
# ...

# %%
electricity_belarus['Year'].values
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014])

# %%
electricity_belarus['Electricity consumption'].values
# Out:
# array([4380.90097164, 4426.0349225 , 3912.88175411, 3450.23928118,
#        3068.34848929, 2789.9744948 , 2806.49606299, 2953.04932292,
#        3016.28761545, 3005.36425705, 2996.30947502, 3009.40248167,
#        3000.74562508, 3063.05693858, 3174.05309232, 3245.37208781,
#        3365.98186514, 3393.90853611, 3481.7435166 , 3298.70360738,
#        3563.63776598, 3628.4572897 , 3697.39748397, 3648.32146049,
#        3679.97884007])

# %% [markdown]
# ### Saving the data

# %%
electricity_belarus.to_csv('per-capita-electricity-consumption-belarus.csv', index=None, header=True)

# %% [markdown]
# ### For each country, get the minimum electricity consumption and the respective year

# %%
df_electricity.loc[df_electricity.groupby('Entity')['Electricity consumption'].idxmin()]
# Out:
#              Entity  Year  Electricity consumption
# 20          Albania  1991               418.453589
# 49          Belarus  1995              2789.974495
# 69           France  1960              1456.693612
# 124           India  1971                98.056459
# 168            Iran  1971               274.134303
# 215       Lithuania  1993              2494.424475
# 237           Spain  1960               494.795600
# 292  United Kingdom  1960              2412.137405
# 347   United States  1960              4049.786629
# 405         Vietnam  1974                33.884598

# %% [markdown]
# The inner part gives you the index where you find the minimum electricity consumption for each country.
#
# The magic happens with the idxmin() function, which gives you the indices where you find the minimum electricity consumption.

# %%
df_electricity.groupby('Entity')['Electricity consumption'].idxmin()
# Out:
# Entity
# Albania            20
# Belarus            49
# France             69
# India             124
# Iran              168
# Lithuania         215
# Spain             237
# United Kingdom    292
# United States     347
# Vietnam           405
# Name: Electricity consumption, dtype: int64

# %% [markdown]
# Then using the loc you can get the data for the row indices returned above.

# %%
df_electricity.loc[df_electricity.groupby('Entity')['Electricity consumption'].idxmin()]
# Out:
#              Entity  Year  Electricity consumption
# 20          Albania  1991               418.453589
# 49          Belarus  1995              2789.974495
# 69           France  1960              1456.693612
# 124           India  1971                98.056459
# 168            Iran  1971               274.134303
# 215       Lithuania  1993              2494.424475
# 237           Spain  1960               494.795600
# 292  United Kingdom  1960              2412.137405
# 347   United States  1960              4049.786629
# 405         Vietnam  1974                33.884598
